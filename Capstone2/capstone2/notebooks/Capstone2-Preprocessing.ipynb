# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import seaborn as sns
from IPython.core.display import display, HTML
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.filterwarnings('ignore')

# %%
#Code from Web, increase width of jupyter
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
df = pd.read_csv('../data/interim/ukexplored.csv', index_col=0, low_memory=False)

# %%
df.head(3)
# Out:
#   Accident_Index 1st_Road_Class Accident_Severity Day_of_Week  \
# 0  200501BS00002              B            Slight   Wednesday
# 1  200501BS00003              C            Slight    Thursday
# 2  200501BS00004              A            Slight      Friday
#
#                Junction_Control                      Junction_Detail  \
# 0           Auto traffic signal                           Crossroads
# 1  Data missing or out of range  Not at junction or within 20 metres
# 2  Data missing or out of range  Not at junction or within 20 metres
#
#         Light_Conditions  Pedestrian_Crossing-Human_Control  \
# 0  Darkness - lights lit                                0.0
# 1  Darkness - lights lit                                0.0
# 2               Daylight                                0.0
#
#    Pedestrian_Crossing-Physical_Facilities Road_Surface_Conditions  ...  \
# 0                                      5.0                     Dry  ...
# 1                                      0.0                     Dry  ...
# 2                                      0.0                     Dry  ...
#
#                         Junction_Location Propulsion_Code  Sex_of_Driver  \
# 0                      Leaving roundabout       Heavy oil           Male
# 1  Not at or within 20 metres of junction       Heavy oil           Male
# 2  Not at or within 20 metres of junction          Petrol         Female
#
#   Towing_and_Articulation Vehicle_Leaving_Carriageway  \
# 0     No tow/articulation   Did not leave carriageway
# 1     No tow/articulation   Did not leave carriageway
# 2     No tow/articulation   Did not leave carriageway
#
#              Vehicle_Manoeuvre  Vehicle_Reference  \
# 0          Slowing or stopping                  1
# 1  Going ahead right-hand bend                  1
# 2            Going ahead other                  1
#
#                            Vehicle_Type Was_Vehicle_Left_Hand_Drive  \
# 0  Bus or coach (17 or more pass seats)                          No
# 1  Bus or coach (17 or more pass seats)                          No
# 2                                   Car                          No
#
#               Datetime
# 0  2005-01-05 17:36:00
# 1  2005-01-06 00:15:00
# 2  2005-01-07 10:35:00
#
# [3 rows x 28 columns]

# %% [markdown]
# # Split into Explanatory 'X' and Target 'y'

# %% [markdown]
# y = df['Accident_Severity']
# X = df.drop(columns = ['Accident_Severity'])

# %%
X.head(3)
# Out:
#   Accident_Index 1st_Road_Class Day_of_Week              Junction_Control  \
# 0  200501BS00002              B   Wednesday           Auto traffic signal
# 1  200501BS00003              C    Thursday  Data missing or out of range
# 2  200501BS00004              A      Friday  Data missing or out of range
#
#                        Junction_Detail       Light_Conditions  \
# 0                           Crossroads  Darkness - lights lit
# 1  Not at junction or within 20 metres  Darkness - lights lit
# 2  Not at junction or within 20 metres               Daylight
#
#    Pedestrian_Crossing-Human_Control  Pedestrian_Crossing-Physical_Facilities  \
# 0                                0.0                                      5.0
# 1                                0.0                                      0.0
# 2                                0.0                                      0.0
#
#   Road_Surface_Conditions           Road_Type  ...  \
# 0                     Dry    Dual carriageway  ...
# 1                     Dry  Single carriageway  ...
# 2                     Dry  Single carriageway  ...
#
#                         Junction_Location  Propulsion_Code Sex_of_Driver  \
# 0                      Leaving roundabout        Heavy oil          Male
# 1  Not at or within 20 metres of junction        Heavy oil          Male
# 2  Not at or within 20 metres of junction           Petrol        Female
#
#   Towing_and_Articulation  Vehicle_Leaving_Carriageway  \
# 0     No tow/articulation    Did not leave carriageway
# 1     No tow/articulation    Did not leave carriageway
# 2     No tow/articulation    Did not leave carriageway
#
#              Vehicle_Manoeuvre Vehicle_Reference  \
# 0          Slowing or stopping                 1
# 1  Going ahead right-hand bend                 1
# 2            Going ahead other                 1
#
#                            Vehicle_Type Was_Vehicle_Left_Hand_Drive  \
# 0  Bus or coach (17 or more pass seats)                          No
# 1  Bus or coach (17 or more pass seats)                          No
# 2                                   Car                          No
#
#               Datetime
# 0  2005-01-05 17:36:00
# 1  2005-01-06 00:15:00
# 2  2005-01-07 10:35:00
#
# [3 rows x 27 columns]
